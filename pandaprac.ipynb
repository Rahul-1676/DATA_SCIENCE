# %% [markdown]
# # Introduction to pandas

# %% [markdown]
# ## what is pandas?

# %%
print("hello world")
# Out:
# hello world

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
print("introduction to pandas")
# Out:
# introduction to pandas

# %% [markdown]
# ## Key Data Structures in pandas
# * Series (1D)
# * dataFrame (2D)

# %%
s = pd.Series([1, 2, 3, 4, 5])

# %%
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
df = pd.DataFrame({    "A": [1, 2, 3, 4, 5],
                      "B": [5, 4, 3, 2, 1], 
                        "C": [2, 3, 4, 5, 6]})

# %%
df
# Out:
#    A  B  C
# 0  1  5  2
# 1  2  4  3
# 2  3  3  4
# 3  4  2  5
# 4  5  1  6

# %%
df = pd.DataFrame({ "names": ["Alice", "Bob", "Charlie", "David"],
                    "ages": [24, 30, 22, 35],   
                    "cities": ["New York", "Los Angeles", "Chicago", "Houston"]})
df
# Out:
#      names  ages       cities
# 0    Alice    24     New York
# 1      Bob    30  Los Angeles
# 2  Charlie    22      Chicago
# 3    David    35      Houston

# %%
import pandas as pd

# Create a sample DataFrame and save it as a CSV
sample_df = pd.DataFrame({
	"Year": [2000, 2001, 2002],
	"CO2": [370.1, 371.2, 372.5],
	"Temperature": [14.3, 14.5, 14.6]
})
sample_df.to_csv("climate_change_dataset.csv", index=False)

# Now read the CSV file
df = pd.read_csv("climate_change_dataset.csv")
df
# Out:
#    Year    CO2  Temperature
# 0  2000  370.1         14.3
# 1  2001  371.2         14.5
# 2  2002  372.5         14.6

# %%
df = pd.read_excel("climate_change_dataset.xlsx", sheet_name="Sheet1")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df = pd.read_excel("climate_change_dataset.xlsx", sheet_name="Sheet1")
#       2 df
#
# File c:\Users\rahul\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
# ...

# %%
df = pd.read_csv("climatechange_dataset.csv")
df
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df = pd.read_csv("climatechange_dataset.csv")
#       2 df
#
# File c:\Users\rahul\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
df = pd.read_csv("data/climate_change_dataset.csv")
df
# Out:
#      Year    Country  Avg Temperature (°C)  CO2 Emissions (Tons/Capita)  \
# 0    2006         UK                   8.9                          9.3
# 1    2019        USA                  31.0                          4.8
# 2    2014     France                  33.9                          2.8
# 3    2010  Argentina                   5.9                          1.8
# 4    2007    Germany                  26.9                          5.6
# ..    ...        ...                   ...                          ...
# 995  2019      India                  23.6                          8.0
# 996  2000         UK                  21.8                         10.0
# 997  2019  Argentina                  23.8                          8.9
# 998  2016  Australia                  21.0                         14.9
# 999  2011    Germany                  24.1                         17.3
#
#      Sea Level Rise (mm)  Rainfall (mm)  Population  Renewable Energy (%)  \
# ...

# %%
import matplotlib.pyplot as plt

plt.bar(df["Year"], df["CO2"])
plt.xlabel("Year")  
plt.ylabel("CO2 Concentration (ppm)")
plt.title("CO2 Concentration Over Years")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 import matplotlib.pyplot as plt
# ----> 3 plt.bar(df["Year"], df["CO2"])
#       4 plt.xlabel("Year")
#       5 plt.ylabel("CO2 Concentration (ppm)")
#
# NameError: name 'df' is not defined

# %%
df = pd.read_csv("data/climate_change_dataset.csv")
df
# Out:
#      Year    Country  Avg Temperature (°C)  CO2 Emissions (Tons/Capita)  \
# 0    2006         UK                   8.9                          9.3
# 1    2019        USA                  31.0                          4.8
# 2    2014     France                  33.9                          2.8
# 3    2010  Argentina                   5.9                          1.8
# 4    2007    Germany                  26.9                          5.6
# ..    ...        ...                   ...                          ...
# 995  2019      India                  23.6                          8.0
# 996  2000         UK                  21.8                         10.0
# 997  2019  Argentina                  23.8                          8.9
# 998  2016  Australia                  21.0                         14.9
# 999  2011    Germany                  24.1                         17.3
#
#      Sea Level Rise (mm)  Rainfall (mm)  Population  Renewable Energy (%)  \
# ...

# %%
df.head()
# Out:
#    Year    Country  Avg Temperature (°C)  CO2 Emissions (Tons/Capita)  \
# 0  2006         UK                   8.9                          9.3
# 1  2019        USA                  31.0                          4.8
# 2  2014     France                  33.9                          2.8
# 3  2010  Argentina                   5.9                          1.8
# 4  2007    Germany                  26.9                          5.6
#
#    Sea Level Rise (mm)  Rainfall (mm)  Population  Renewable Energy (%)  \
# 0                  3.1           1441   530911230                  20.4
# 1                  4.2           2407   107364344                  49.2
# 2                  2.2           1241   441101758                  33.3
# 3                  3.2           1892  1069669579                  23.7
# 4                  2.4           1743   124079175                  12.5
#
#    Extreme Weather Events  Forest Area (%)
# 0                      14             59.8
# ...

# %%
df.tail()
# Out:
#      Year    Country  Avg Temperature (°C)  CO2 Emissions (Tons/Capita)  \
# 995  2019      India                  23.6                          8.0
# 996  2000         UK                  21.8                         10.0
# 997  2019  Argentina                  23.8                          8.9
# 998  2016  Australia                  21.0                         14.9
# 999  2011    Germany                  24.1                         17.3
#
#      Sea Level Rise (mm)  Rainfall (mm)  Population  Renewable Energy (%)  \
# 995                  1.2           1365  1358019778                  10.0
# 996                  2.2           1273   876123161                  14.9
# 997                  4.7            891  1120533308                  25.9
# 998                  3.1           1136   380662109                  24.5
# 999                  2.1           2854   398407112                  41.0
#
#      Extreme Weather Events  Forest Area (%)
# ...

# %%
df.describe()
# Out:
#               Year  Avg Temperature (°C)  CO2 Emissions (Tons/Capita)  \
# count  1000.000000           1000.000000                  1000.000000
# mean   2011.432000             19.883100                    10.425800
# std       7.147199              8.542897                     5.614665
# min    2000.000000              5.000000                     0.500000
# 25%    2005.000000             12.175000                     5.575000
# 50%    2012.000000             20.100000                    10.700000
# 75%    2018.000000             27.225000                    15.400000
# max    2023.000000             34.900000                    20.000000
#
#        Sea Level Rise (mm)  Rainfall (mm)    Population  Renewable Energy (%)  \
# count          1000.000000    1000.000000  1.000000e+03           1000.000000
# mean              3.009600    1738.761000  7.053830e+08             27.300500
# std               1.146081     708.976616  4.093910e+08             12.970808
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Year                         1000 non-null   int64
#  1   Country                      1000 non-null   object
#  2   Avg Temperature (°C)         1000 non-null   float64
#  3   CO2 Emissions (Tons/Capita)  1000 non-null   float64
#  4   Sea Level Rise (mm)          1000 non-null   float64
#  5   Rainfall (mm)                1000 non-null   int64
#  6   Population                   1000 non-null   int64
#  7   Renewable Energy (%)         1000 non-null   float64
#  8   Extreme Weather Events       1000 non-null   int64
#  9   Forest Area (%)              1000 non-null   float64
# dtypes: float64(5), int64(4), object(1)
# memory usage: 78.3+ KB

# %% [markdown]
# ## Data selection

# %%
type(df["Year"])
# Out:
# pandas.core.series.Series

# %%
df["Year"]
# Out:
# 0      2006
# 1      2019
# 2      2014
# 3      2010
# 4      2007
#        ...
# 995    2019
# 996    2000
# 997    2019
# 998    2016
# 999    2011
# Name: Year, Length: 1000, dtype: int64

# %%
df[["Year", "Population",]  ]
# Out:
#      Year  Population
# 0    2006   530911230
# 1    2019   107364344
# 2    2014   441101758
# 3    2010  1069669579
# 4    2007   124079175
# ..    ...         ...
# 995  2019  1358019778
# 996  2000   876123161
# 997  2019  1120533308
# 998  2016   380662109
# 999  2011   398407112
#
# [1000 rows x 2 columns]

# %%
df.iloc[0]  # First row
# Out:
# Year                                2006
# Country                               UK
# Avg Temperature (°C)                 8.9
# CO2 Emissions (Tons/Capita)          9.3
# Sea Level Rise (mm)                  3.1
# Rainfall (mm)                       1441
# Population                     530911230
# Renewable Energy (%)                20.4
# Extreme Weather Events                14
# Forest Area (%)                     59.8
# Name: 0, dtype: object

# %%
df = pd.read_csv("data/climate_change_dataset.csv", index_col="Year")
df
# Out:
#         Country  Avg Temperature (°C)  CO2 Emissions (Tons/Capita)  \
# Year
# 2006         UK                   8.9                          9.3
# 2019        USA                  31.0                          4.8
# 2014     France                  33.9                          2.8
# 2010  Argentina                   5.9                          1.8
# 2007    Germany                  26.9                          5.6
# ...         ...                   ...                          ...
# 2019      India                  23.6                          8.0
# 2000         UK                  21.8                         10.0
# 2019  Argentina                  23.8                          8.9
# 2016  Australia                  21.0                         14.9
# 2011    Germany                  24.1                         17.3
#
#       Sea Level Rise (mm)  Rainfall (mm)  Population  Renewable Energy (%)  \
# Year
# ...

# %%
df.head()
# Out:
#         Country  Avg Temperature (°C)  CO2 Emissions (Tons/Capita)  \
# Year
# 2006         UK                   8.9                          9.3
# 2019        USA                  31.0                          4.8
# 2014     France                  33.9                          2.8
# 2010  Argentina                   5.9                          1.8
# 2007    Germany                  26.9                          5.6
#
#       Sea Level Rise (mm)  Rainfall (mm)  Population  Renewable Energy (%)  \
# Year
# 2006                  3.1           1441   530911230                  20.4
# 2019                  4.2           2407   107364344                  49.2
# 2014                  2.2           1241   441101758                  33.3
# 2010                  3.2           1892  1069669579                  23.7
# 2007                  2.4           1743   124079175                  12.5
#
#       Extreme Weather Events  Forest Area (%)
# Year
# ...

# %%
df.dropna()
# Out:
#         Country  Avg Temperature (°C)  CO2 Emissions (Tons/Capita)  \
# Year
# 2006         UK                   8.9                          9.3
# 2019        USA                  31.0                          4.8
# 2014     France                  33.9                          2.8
# 2010  Argentina                   5.9                          1.8
# 2007    Germany                  26.9                          5.6
# ...         ...                   ...                          ...
# 2019      India                  23.6                          8.0
# 2000         UK                  21.8                         10.0
# 2019  Argentina                  23.8                          8.9
# 2016  Australia                  21.0                         14.9
# 2011    Germany                  24.1                         17.3
#
#       Sea Level Rise (mm)  Rainfall (mm)  Population  Renewable Energy (%)  \
# Year
# ...

# %%
df.fillna(0,inplace=True)

# %%
df
# Out:
#         Country  Avg Temperature (°C)  CO2 Emissions (Tons/Capita)  \
# Year
# 2006         UK                   8.9                          9.3
# 2019        USA                  31.0                          4.8
# 2014     France                  33.9                          2.8
# 2010  Argentina                   5.9                          1.8
# 2007    Germany                  26.9                          5.6
# ...         ...                   ...                          ...
# 2019      India                  23.6                          8.0
# 2000         UK                  21.8                         10.0
# 2019  Argentina                  23.8                          8.9
# 2016  Australia                  21.0                         14.9
# 2011    Germany                  24.1                         17.3
#
#       Sea Level Rise (mm)  Rainfall (mm)  Population  Renewable Energy (%)  \
# Year
# ...

# %%
df.rename(columns={"CO2": "CO2 Concentration", "Temperature": "Global Temperature"}, inplace=True)

# %%
df
# Out:
#         Country  Avg Temperature (°C)  CO2 Emissions (Tons/Capita)  \
# Year
# 2006         UK                   8.9                          9.3
# 2019        USA                  31.0                          4.8
# 2014     France                  33.9                          2.8
# 2010  Argentina                   5.9                          1.8
# 2007    Germany                  26.9                          5.6
# ...         ...                   ...                          ...
# 2019      India                  23.6                          8.0
# 2000         UK                  21.8                         10.0
# 2019  Argentina                  23.8                          8.9
# 2016  Australia                  21.0                         14.9
# 2011    Germany                  24.1                         17.3
#
#       Sea Level Rise (mm)  Rainfall (mm)  Population  Renewable Energy (%)  \
# Year
# ...

# %%
df.rename(columns = {"Avg Temperature": "Average Temperature"}, inplace=True)
df
# Out:
#         Country  Avg Temperature (°C)  CO2 Emissions (Tons/Capita)  \
# Year
# 2006         UK                   8.9                          9.3
# 2019        USA                  31.0                          4.8
# 2014     France                  33.9                          2.8
# 2010  Argentina                   5.9                          1.8
# 2007    Germany                  26.9                          5.6
# ...         ...                   ...                          ...
# 2019      India                  23.6                          8.0
# 2000         UK                  21.8                         10.0
# 2019  Argentina                  23.8                          8.9
# 2016  Australia                  21.0                         14.9
# 2011    Germany                  24.1                         17.3
#
#       Sea Level Rise (mm)  Rainfall (mm)  Population  Renewable Energy (%)  \
# Year
# ...

# %%
df.rename(columns = {"Country": "Nation"}, inplace=True)
df
# Out:
#          Nation  Avg Temperature (°C)  CO2 Emissions (Tons/Capita)  \
# Year
# 2006         UK                   8.9                          9.3
# 2019        USA                  31.0                          4.8
# 2014     France                  33.9                          2.8
# 2010  Argentina                   5.9                          1.8
# 2007    Germany                  26.9                          5.6
# ...         ...                   ...                          ...
# 2019      India                  23.6                          8.0
# 2000         UK                  21.8                         10.0
# 2019  Argentina                  23.8                          8.9
# 2016  Australia                  21.0                         14.9
# 2011    Germany                  24.1                         17.3
#
#       Sea Level Rise (mm)  Rainfall (mm)  Population  Renewable Energy (%)  \
# Year
# ...

# %%
df.describe()
# Out:
#        Avg Temperature (°C)  CO2 Emissions (Tons/Capita)  Sea Level Rise (mm)  \
# count           1000.000000                  1000.000000          1000.000000
# mean              19.883100                    10.425800             3.009600
# std                8.542897                     5.614665             1.146081
# min                5.000000                     0.500000             1.000000
# 25%               12.175000                     5.575000             2.000000
# 50%               20.100000                    10.700000             3.000000
# 75%               27.225000                    15.400000             4.000000
# max               34.900000                    20.000000             5.000000
#
#        Rainfall (mm)    Population  Renewable Energy (%)  \
# count    1000.000000  1.000000e+03           1000.000000
# mean     1738.761000  7.053830e+08             27.300500
# std       708.976616  4.093910e+08             12.970808
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 2006 to 2011
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Nation                       1000 non-null   object
#  1   Avg Temperature (°C)         1000 non-null   float64
#  2   CO2 Emissions (Tons/Capita)  1000 non-null   float64
#  3   Sea Level Rise (mm)          1000 non-null   float64
#  4   Rainfall (mm)                1000 non-null   int64
#  5   Population                   1000 non-null   int64
#  6   Renewable Energy (%)         1000 non-null   float64
#  7   Extreme Weather Events       1000 non-null   int64
#  8   Forest Area (%)              1000 non-null   float64
# dtypes: float64(5), int64(3), object(1)
# memory usage: 78.1+ KB

# %%
df['Avg Temperature (°C)'] = df['Avg Temperature (°C)'].astype(int)

# %%
df['Avg Temperature (°C)'] = df['Avg Temperature (°C)'].astype(float)

# %%
df
# Out:
#          Nation  Avg Temperature (°C)  CO2 Emissions (Tons/Capita)  \
# Year
# 2006         UK                   8.0                          9.3
# 2019        USA                  31.0                          4.8
# 2014     France                  33.0                          2.8
# 2010  Argentina                   5.0                          1.8
# 2007    Germany                  26.0                          5.6
# ...         ...                   ...                          ...
# 2019      India                  23.0                          8.0
# 2000         UK                  21.0                         10.0
# 2019  Argentina                  23.0                          8.9
# 2016  Australia                  21.0                         14.9
# 2011    Germany                  24.0                         17.3
#
#       Sea Level Rise (mm)  Rainfall (mm)  Population  Renewable Energy (%)  \
# Year
# ...

# %%
df['Avg Temperature (°C)'] = df['Avg Temperature (°C)'].astype(str)

# %%
df
# Out:
#          Nation Avg Temperature (°C)  CO2 Emissions (Tons/Capita)  \
# Year
# 2006         UK                  8.0                          9.3
# 2019        USA                 31.0                          4.8
# 2014     France                 33.0                          2.8
# 2010  Argentina                  5.0                          1.8
# 2007    Germany                 26.0                          5.6
# ...         ...                  ...                          ...
# 2019      India                 23.0                          8.0
# 2000         UK                 21.0                         10.0
# 2019  Argentina                 23.0                          8.9
# 2016  Australia                 21.0                         14.9
# 2011    Germany                 24.0                         17.3
#
#       Sea Level Rise (mm)  Rainfall (mm)  Population  Renewable Energy (%)  \
# Year
# 2006                  3.1           1441   530911230                  20.4
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of          Nation Avg Temperature (°C)  CO2 Emissions (Tons/Capita)  \
# Year
# 2006         UK                  8.0                          9.3
# 2019        USA                 31.0                          4.8
# 2014     France                 33.0                          2.8
# 2010  Argentina                  5.0                          1.8
# 2007    Germany                 26.0                          5.6
# ...         ...                  ...                          ...
# 2019      India                 23.0                          8.0
# 2000         UK                 21.0                         10.0
# 2019  Argentina                 23.0                          8.9
# 2016  Australia                 21.0                         14.9
# 2011    Germany                 24.0                         17.3
#
#       Sea Level Rise (mm)  Rainfall (mm)  Population  Renewable Energy (%)  \
# Year
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 2006 to 2011
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Nation                       1000 non-null   object
#  1   Avg Temperature (°C)         1000 non-null   object
#  2   CO2 Emissions (Tons/Capita)  1000 non-null   float64
#  3   Sea Level Rise (mm)          1000 non-null   float64
#  4   Rainfall (mm)                1000 non-null   int64
#  5   Population                   1000 non-null   int64
#  6   Renewable Energy (%)         1000 non-null   float64
#  7   Extreme Weather Events       1000 non-null   int64
#  8   Forest Area (%)              1000 non-null   float64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 78.1+ KB

# %%
df["Avg Temperature (°C)"][0]   = "20.5"  # This will raise an error if the column is not of type string
# Out:
# C:\Users\rahul\AppData\Local\Temp\ipykernel_364\1268032155.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Avg Temperature (°C)"][0]   = "20.5"  # This will raise an error if the column is not of type string

# %%
df
# Out:
#          Nation Avg Temperature (°C)  CO2 Emissions (Tons/Capita)  \
# Year
# 2006         UK                  8.0                          9.3
# 2019        USA                 31.0                          4.8
# 2014     France                 33.0                          2.8
# 2010  Argentina                  5.0                          1.8
# 2007    Germany                 26.0                          5.6
# ...         ...                  ...                          ...
# 2019      India                 23.0                          8.0
# 2000         UK                 21.0                         10.0
# 2019  Argentina                 23.0                          8.9
# 2016  Australia                 21.0                         14.9
# 2011    Germany                 24.0                         17.3
#
#       Sea Level Rise (mm)  Rainfall (mm)  Population  Renewable Energy (%)  \
# Year
# 2006                  3.1           1441   530911230                  20.4
# ...

# %%
df.head()
# Out:
#          Nation Avg Temperature (°C)  CO2 Emissions (Tons/Capita)  \
# Year
# 2006         UK                  8.0                          9.3
# 2019        USA                 31.0                          4.8
# 2014     France                 33.0                          2.8
# 2010  Argentina                  5.0                          1.8
# 2007    Germany                 26.0                          5.6
#
#       Sea Level Rise (mm)  Rainfall (mm)  Population  Renewable Energy (%)  \
# Year
# 2006                  3.1           1441   530911230                  20.4
# 2019                  4.2           2407   107364344                  49.2
# 2014                  2.2           1241   441101758                  33.3
# 2010                  3.2           1892  1069669579                  23.7
# 2007                  2.4           1743   124079175                  12.5
#
#       Extreme Weather Events  Forest Area (%)
# Year
# 2006                      14             59.8
# ...

# %%
    df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 2006 to 2011
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Nation                       1000 non-null   object
#  1   Avg Temperature (°C)         1000 non-null   object
#  2   CO2 Emissions (Tons/Capita)  1000 non-null   float64
#  3   Sea Level Rise (mm)          1000 non-null   float64
#  4   Rainfall (mm)                1000 non-null   int64
#  5   Population                   1000 non-null   int64
#  6   Renewable Energy (%)         1000 non-null   float64
#  7   Extreme Weather Events       1000 non-null   int64
#  8   Forest Area (%)              1000 non-null   float64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 110.4+ KB

# %%
df['Avg Temperature (°C)']  = df['Avg Temperature (°C)'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 2006 to 2011
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Nation                       1000 non-null   object
#  1   Avg Temperature (°C)         1000 non-null   float64
#  2   CO2 Emissions (Tons/Capita)  1000 non-null   float64
#  3   Sea Level Rise (mm)          1000 non-null   float64
#  4   Rainfall (mm)                1000 non-null   int64
#  5   Population                   1000 non-null   int64
#  6   Renewable Energy (%)         1000 non-null   float64
#  7   Extreme Weather Events       1000 non-null   int64
#  8   Forest Area (%)              1000 non-null   float64
# dtypes: float64(5), int64(3), object(1)
# memory usage: 110.4+ KB

# %%
df.head()
# Out:
#          Nation  Avg Temperature (°C)  CO2 Emissions (Tons/Capita)  \
# Year
# 2006         UK                   8.0                          9.3
# 2019        USA                  31.0                          4.8
# 2014     France                  33.0                          2.8
# 2010  Argentina                   5.0                          1.8
# 2007    Germany                  26.0                          5.6
#
#       Sea Level Rise (mm)  Rainfall (mm)  Population  Renewable Energy (%)  \
# Year
# 2006                  3.1           1441   530911230                  20.4
# 2019                  4.2           2407   107364344                  49.2
# 2014                  2.2           1241   441101758                  33.3
# 2010                  3.2           1892  1069669579                  23.7
# 2007                  2.4           1743   124079175                  12.5
#
#       Extreme Weather Events  Forest Area (%)
# Year
# ...

# %%
df.head()
df.tail()
# Out:
#          Nation  Avg Temperature (°C)  CO2 Emissions (Tons/Capita)  \
# Year
# 2019      India                  23.0                          8.0
# 2000         UK                  21.0                         10.0
# 2019  Argentina                  23.0                          8.9
# 2016  Australia                  21.0                         14.9
# 2011    Germany                  24.0                         17.3
#
#       Sea Level Rise (mm)  Rainfall (mm)  Population  Renewable Energy (%)  \
# Year
# 2019                  1.2           1365  1358019778                  10.0
# 2000                  2.2           1273   876123161                  14.9
# 2019                  4.7            891  1120533308                  25.9
# 2016                  3.1           1136   380662109                  24.5
# 2011                  2.1           2854   398407112                  41.0
#
#       Extreme Weather Events  Forest Area (%)
# Year
# ...

# %%
df.head()
df.tail()
df.describe()
df.describe()
df.info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 2006 to 2011
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Nation                       1000 non-null   object
#  1   Avg Temperature (°C)         1000 non-null   float64
#  2   CO2 Emissions (Tons/Capita)  1000 non-null   float64
#  3   Sea Level Rise (mm)          1000 non-null   float64
#  4   Rainfall (mm)                1000 non-null   int64
#  5   Population                   1000 non-null   int64
#  6   Renewable Energy (%)         1000 non-null   float64
#  7   Extreme Weather Events       1000 non-null   int64
#  8   Forest Area (%)              1000 non-null   float64
# dtypes: float64(5), int64(3), object(1)
# memory usage: 110.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 2006 to 2011
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ...

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 2006 to 2011
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Nation                       1000 non-null   object
#  1   Avg Temperature (°C)         1000 non-null   float64
#  2   CO2 Emissions (Tons/Capita)  1000 non-null   float64
#  3   Sea Level Rise (mm)          1000 non-null   float64
#  4   Rainfall (mm)                1000 non-null   int64
#  5   Population                   1000 non-null   int64
#  6   Renewable Energy (%)         1000 non-null   float64
#  7   Extreme Weather Events       1000 non-null   int64
#  8   Forest Area (%)              1000 non-null   float64
# dtypes: float64(5), int64(3), object(1)
# memory usage: 110.4+ KB
#        Avg Temperature (°C)  CO2 Emissions (Tons/Capita)  Sea Level Rise (mm)  \
# count           1000.000000                  1000.000000          1000.000000
# ...

# %%
len(df)
# Out:
# 1000

# %%
df["Nation"].unique()
# Out:
# array(['UK', 'USA', 'France', 'Argentina', 'Germany', 'China',
#        'South Africa', 'Australia', 'Indonesia', 'Brazil', 'India',
#        'Russia', 'Canada', 'Mexico', 'Japan'], dtype=object)

# %%
df["Nation"].iloc[0]
# Out:
# 'UK'

# %%
df["Zeros"]=[0 for i in range(len(df))]
df
# Out:
#          Nation  Avg Temperature (°C)  CO2 Emissions (Tons/Capita)  \
# Year
# 2006         UK                   8.0                          9.3
# 2019        USA                  31.0                          4.8
# 2014     France                  33.0                          2.8
# 2010  Argentina                   5.0                          1.8
# 2007    Germany                  26.0                          5.6
# ...         ...                   ...                          ...
# 2019      India                  23.0                          8.0
# 2000         UK                  21.0                         10.0
# 2019  Argentina                  23.0                          8.9
# 2016  Australia                  21.0                         14.9
# 2011    Germany                  24.0                         17.3
#
#       Sea Level Rise (mm)  Rainfall (mm)  Population  Renewable Energy (%)  \
# Year
# ...

# %%
def fx(x):
    return x / 2
df["half of population"] = df["Population"] .apply(fx)

# %%
df
# Out:
#          Nation  Avg Temperature (°C)  CO2 Emissions (Tons/Capita)  \
# Year
# 2006         UK                   8.0                          9.3
# 2019        USA                  31.0                          4.8
# 2014     France                  33.0                          2.8
# 2010  Argentina                   5.0                          1.8
# 2007    Germany                  26.0                          5.6
# ...         ...                   ...                          ...
# 2019      India                  23.0                          8.0
# 2000         UK                  21.0                         10.0
# 2019  Argentina                  23.0                          8.9
# 2016  Australia                  21.0                         14.9
# 2011    Germany                  24.0                         17.3
#
#       Sea Level Rise (mm)  Rainfall (mm)  Population  Renewable Energy (%)  \
# Year
# ...

# %%
df["half of population"].astype(int)
# Out:
# Year
# 2006    265455615
# 2019     53682172
# 2014    220550879
# 2010    534834789
# 2007     62039587
#           ...
# 2019    679009889
# 2000    438061580
# 2019    560266654
# 2016    190331054
# 2011    199203556
# Name: half of population, Length: 1000, dtype: int32

# %%
df["half of population"] = df["half of population"].astype(int)
df
# Out:
#          Nation  Avg Temperature (°C)  CO2 Emissions (Tons/Capita)  \
# Year
# 2006         UK                   8.0                          9.3
# 2019        USA                  31.0                          4.8
# 2014     France                  33.0                          2.8
# 2010  Argentina                   5.0                          1.8
# 2007    Germany                  26.0                          5.6
# ...         ...                   ...                          ...
# 2019      India                  23.0                          8.0
# 2000         UK                  21.0                         10.0
# 2019  Argentina                  23.0                          8.9
# 2016  Australia                  21.0                         14.9
# 2011    Germany                  24.0                         17.3
#
#       Sea Level Rise (mm)  Rainfall (mm)  Population  Renewable Energy (%)  \
# Year
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 2006 to 2011
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Nation                       1000 non-null   object
#  1   Avg Temperature (°C)         1000 non-null   float64
#  2   CO2 Emissions (Tons/Capita)  1000 non-null   float64
#  3   Sea Level Rise (mm)          1000 non-null   float64
#  4   Rainfall (mm)                1000 non-null   int64
#  5   Population                   1000 non-null   int64
#  6   Renewable Energy (%)         1000 non-null   float64
#  7   Extreme Weather Events       1000 non-null   int64
#  8   Forest Area (%)              1000 non-null   float64
#  9   Zeros                        1000 non-null   int64
#  10  half of population           1000 non-null   int32
# dtypes: float64(5), int32(1), int64(4), object(1)
# memory usage: 122.1+ KB

# %%
df["Zeros"]
# Out:
# Year
# 2006    0
# 2019    0
# 2014    0
# 2010    0
# 2007    0
#        ..
# 2019    0
# 2000    0
# 2019    0
# 2016    0
# 2011    0
# Name: Zeros, Length: 1000, dtype: int64

# %%
df.__reduce__
# Out:
# <function DataFrame.__reduce__()>

# %%
df
# Out:
#          Nation  Avg Temperature (°C)  CO2 Emissions (Tons/Capita)  \
# Year
# 2006         UK                   8.0                          9.3
# 2019        USA                  31.0                          4.8
# 2014     France                  33.0                          2.8
# 2010  Argentina                   5.0                          1.8
# 2007    Germany                  26.0                          5.6
# ...         ...                   ...                          ...
# 2019      India                  23.0                          8.0
# 2000         UK                  21.0                         10.0
# 2019  Argentina                  23.0                          8.9
# 2016  Australia                  21.0                         14.9
# 2011    Germany                  24.0                         17.3
#
#       Sea Level Rise (mm)  Rainfall (mm)  Population  Renewable Energy (%)  \
# Year
# ...

# %%
# Out:
#   Cell In[82], line 1
#     < s._reduce__() >
#     ^
# SyntaxError: invalid syntax

# %%
df1 = pd.DataFrame({
    "Year": [2000, 2001, 2002],
    "CO2": [370.1, 371.2, 372.5],
    "Temperature": [14.3, 14.5, 14.6]
})
df1
# Out:
#    Year    CO2  Temperature
# 0  2000  370.1         14.3
# 1  2001  371.2         14.5
# 2  2002  372.5         14.6

# %%
df2 = pd.DataFrame({
    "Year": [2003, 2004, 2005, 2006], 
    "CO2": [373.0, 374.1, 375.2, 376.3],
    "Temperature": [14.7, 14.8, 14.9, 15.0]   
})
df2
# Out:
#    Year    CO2  Temperature
# 0  2003  373.0         14.7
# 1  2004  374.1         14.8
# 2  2005  375.2         14.9
# 3  2006  376.3         15.0

# %%
pd.concat([df1, df2])
# Out:
#    Year    CO2  Temperature
# 0  2000  370.1         14.3
# 1  2001  371.2         14.5
# 2  2002  372.5         14.6
# 0  2003  373.0         14.7
# 1  2004  374.1         14.8
# 2  2005  375.2         14.9
# 3  2006  376.3         15.0

# %%
df1 = pd.DataFrame({    "Year": [2000, 2001, 2002],
    "CO2": [370.1, 371.2, 372.5],
    "Temperature": [14.3, 14.5, 14.6]
})
df1
# Out:
#    Year    CO2  Temperature
# 0  2000  370.1         14.3
# 1  2001  371.2         14.5
# 2  2002  372.5         14.6

# %%
df2 = pd.DataFrame({
    "Year" : [2000, 2002],
    
    "Population": [6.1, 6.2]
})
df2
# Out:
#    Year  Population
# 0  2000         6.1
# 1  2002         6.2

# %%
pd.merge(df1, df2, on="Year")
# Out:
#    Year    CO2  Temperature  Population
# 0  2000  370.1         14.3         6.1
# 1  2002  372.5         14.6         6.2

# %%
import pandas as pd

# %%
df = pd.read_csv("data/climatechangeds.csv")
df
# Out:
#     Year Country  Average Temperature (°C)  CO2 Emission per Capita (tons)  \
# 0   1975   India                      18.2                             1.2
# 1   1976   India                      24.4                             5.7
# 2   1977   India                      15.7                            12.5
# 3   1978   India                      22.9                            11.6
# 4   1979   India                       9.8                             4.5
# 5   1980   India                      15.6                             3.6
# 6   1981   India                      17.2                             1.5
# 7   1982   India                      25.8                             6.5
# 8   1983   India                      26.3                             8.9
# 9   1984   India                      20.1                            19.1
# 10  1985   India                      13.1                            14.1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 10 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Year                            51 non-null     int64
#  1   Country                         51 non-null     object
#  2   Average Temperature (°C)        51 non-null     float64
#  3   CO2 Emission per Capita (tons)  51 non-null     float64
#  4   Population                      51 non-null     int64
#  5   Sea Level Rise (mm)             51 non-null     float64
#  6   Rainfall (mm/year)              51 non-null     int64
#  7   Extreme Weather Events          51 non-null     int64
#  8   Renewable Energy (%)            51 non-null     float64
#  9   Forest Area (%)                 51 non-null     float64
# dtypes: float64(5), int64(4), object(1)
# memory usage: 4.1+ KB

# %%
df.describe()
# Out:
#               Year  Average Temperature (°C)  CO2 Emission per Capita (tons)  \
# count    51.000000                 51.000000                       51.000000
# mean   2000.000000                 17.462745                       11.231373
# std      14.866069                  5.609170                        5.477718
# min    1975.000000                  8.100000                        1.200000
# 25%    1987.500000                 12.600000                        7.100000
# 50%    2000.000000                 17.600000                       11.900000
# 75%    2012.500000                 22.650000                       15.750000
# max    2025.000000                 26.600000                       19.900000
#
#          Population  Sea Level Rise (mm)  Rainfall (mm/year)  \
# count  5.100000e+01            51.000000           51.000000
# mean   7.321264e+08             3.005686         1785.549020
# std    4.240662e+08             0.959348          759.440803
# ...

# %%
df.loc()

# %%
type(df.loc())
# Out:
# pandas.core.indexing._LocIndexer

# %%
df.head()
df.tail()
# Out:
#     Year Country  Average Temperature (°C)  CO2 Emission per Capita (tons)  \
# 46  2021   India                      19.8                            19.9
# 47  2022   India                      17.6                            18.2
# 48  2023   India                      16.3                            12.8
# 49  2024   India                      23.4                            15.8
# 50  2025   India                      14.9                            13.0
#
#     Population  Sea Level Rise (mm)  Rainfall (mm/year)  \
# 46  1296225328                 2.18                 819
# 47  1113027417                 3.66                1808
# 48   541476530                 4.23                 312
# 49  1050481919                 4.29                 829
# 50   821651641                 1.66                1174
#
#     Extreme Weather Events  Renewable Energy (%)  Forest Area (%)
# 46                      17                  12.1             33.0
# ...

# %%
df.head()
# Out:
#    Year Country  Average Temperature (°C)  CO2 Emission per Capita (tons)  \
# 0  1975   India                      18.2                             1.2
# 1  1976   India                      24.4                             5.7
# 2  1977   India                      15.7                            12.5
# 3  1978   India                      22.9                            11.6
# 4  1979   India                       9.8                             4.5
#
#    Population  Sea Level Rise (mm)  Rainfall (mm/year)  \
# 0   493595773                 2.53                1744
# 1    88141970                 3.85                2478
# 2  1246145121                 3.38                2877
# 3  1190247723                 1.85                1880
# 4   833086475                 1.70                 523
#
#    Extreme Weather Events  Renewable Energy (%)  Forest Area (%)
# 0                       8                  61.2             13.5
# ...

# %%
len(df)
# Out:
# 51

# %%
df.loc(0)  # First row

# %%
df["Country"].unique()
# Out:
# array(['India'], dtype=object)

# %%
df["Year"].iloc[0]  # First value in the "Year" column
# Out:
# 1975

# %%
df["Country"] = df["Country"].astype(str)  # Convert "Country" column to string type

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 10 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Year                            51 non-null     int64
#  1   Country                         51 non-null     object
#  2   Average Temperature (°C)        51 non-null     float64
#  3   CO2 Emission per Capita (tons)  51 non-null     float64
#  4   Population                      51 non-null     int64
#  5   Sea Level Rise (mm)             51 non-null     float64
#  6   Rainfall (mm/year)              51 non-null     int64
#  7   Extreme Weather Events          51 non-null     int64
#  8   Renewable Energy (%)            51 non-null     float64
#  9   Forest Area (%)                 51 non-null     float64
# dtypes: float64(5), int64(4), object(1)
# memory usage: 4.1+ KB

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
import pandas as pd

df = pd.read_csv("data/climatechangeds.csv")  # or however you loaded the data

df.rename(columns={"Country": "Nation"}, inplace=True)
print(df.head())
# Out:
#    Year Nation  Average Temperature (°C)  CO2 Emission per Capita (tons)  \
# 0  1975  India                      18.2                             1.2
# 1  1976  India                      24.4                             5.7
# 2  1977  India                      15.7                            12.5
# 3  1978  India                      22.9                            11.6
# 4  1979  India                       9.8                             4.5
#
#    Population  Sea Level Rise (mm)  Rainfall (mm/year)  \
# 0   493595773                 2.53                1744
# 1    88141970                 3.85                2478
# 2  1246145121                 3.38                2877
# 3  1190247723                 1.85                1880
# 4   833086475                 1.70                 523
#
#    Extreme Weather Events  Renewable Energy (%)  Forest Area (%)
# 0                       8                  61.2             13.5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 10 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Year                            51 non-null     int64
#  1   Nation                          51 non-null     object
#  2   Average Temperature (°C)        51 non-null     float64
#  3   CO2 Emission per Capita (tons)  51 non-null     float64
#  4   Population                      51 non-null     int64
#  5   Sea Level Rise (mm)             51 non-null     float64
#  6   Rainfall (mm/year)              51 non-null     int64
#  7   Extreme Weather Events          51 non-null     int64
#  8   Renewable Energy (%)            51 non-null     float64
#  9   Forest Area (%)                 51 non-null     float64
# dtypes: float64(5), int64(4), object(1)
# memory usage: 4.1+ KB

# %%
df.describe()
# Out:
#               Year  Average Temperature (°C)  CO2 Emission per Capita (tons)  \
# count    51.000000                 51.000000                       51.000000
# mean   2000.000000                 17.462745                       11.231373
# std      14.866069                  5.609170                        5.477718
# min    1975.000000                  8.100000                        1.200000
# 25%    1987.500000                 12.600000                        7.100000
# 50%    2000.000000                 17.600000                       11.900000
# 75%    2012.500000                 22.650000                       15.750000
# max    2025.000000                 26.600000                       19.900000
#
#          Population  Sea Level Rise (mm)  Rainfall (mm/year)  \
# count  5.100000e+01            51.000000           51.000000
# mean   7.321264e+08             3.005686         1785.549020
# std    4.240662e+08             0.959348          759.440803
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
print(df.columns.tolist())
# Out:
# ['Year', 'Nation', 'Average Temperature (°C)', 'CO2 Emission per Capita (tons)', 'Population', 'Sea Level Rise (mm)', 'Rainfall (mm/year)', 'Extreme Weather Events', 'Renewable Energy (%)', 'Forest Area (%)']

# %%
df.drop(["Country"], axis=1)
# Out:
#     Year  Average Temperature (Â°C)  CO2 Emission per Capita (tons)  \
# 0   1975                       18.2                             1.2
# 1   1976                       24.4                             5.7
# 2   1977                       15.7                            12.5
# 3   1978                       22.9                            11.6
# 4   1979                        9.8                             4.5
# 5   1980                       15.6                             3.6
# 6   1981                       17.2                             1.5
# 7   1982                       25.8                             6.5
# 8   1983                       26.3                             8.9
# 9   1984                       20.1                            19.1
# 10  1985                       13.1                            14.1
# 11  1986                       26.6                            11.5
# 12  1987                       10.7                             5.6
# ...

# %%
# The column "Nation" does not exist in df, so we drop "Country" instead if that's intended
df.drop(["Country"], axis=1, inplace=True)
df
# Out:
#     Year  Average Temperature (Â°C)  CO2 Emission per Capita (tons)  \
# 0   1975                       18.2                             1.2
# 1   1976                       24.4                             5.7
# 2   1977                       15.7                            12.5
# 3   1978                       22.9                            11.6
# 4   1979                        9.8                             4.5
# 5   1980                       15.6                             3.6
# 6   1981                       17.2                             1.5
# 7   1982                       25.8                             6.5
# 8   1983                       26.3                             8.9
# 9   1984                       20.1                            19.1
# 10  1985                       13.1                            14.1
# 11  1986                       26.6                            11.5
# 12  1987                       10.7                             5.6
# ...

# %%
df
# Out:
#     Year  Average Temperature (Â°C)  CO2 Emission per Capita (tons)  \
# 0   1975                       18.2                             1.2
# 1   1976                       24.4                             5.7
# 2   1977                       15.7                            12.5
# 3   1978                       22.9                            11.6
# 4   1979                        9.8                             4.5
# 5   1980                       15.6                             3.6
# 6   1981                       17.2                             1.5
# 7   1982                       25.8                             6.5
# 8   1983                       26.3                             8.9
# 9   1984                       20.1                            19.1
# 10  1985                       13.1                            14.1
# 11  1986                       26.6                            11.5
# 12  1987                       10.7                             5.6
# ...

# %%
df.head(
    
)
# Out:
#    Year  Average Temperature (Â°C)  CO2 Emission per Capita (tons)  \
# 0  1975                       18.2                             1.2
# 1  1976                       24.4                             5.7
# 2  1977                       15.7                            12.5
# 3  1978                       22.9                            11.6
# 4  1979                        9.8                             4.5
#
#    Population  Sea Level Rise (mm)  Rainfall (mm/year)  \
# 0   493595773                 2.53                1744
# 1    88141970                 3.85                2478
# 2  1246145121                 3.38                2877
# 3  1190247723                 1.85                1880
# 4   833086475                 1.70                 523
#
#    Extreme Weather Events  Renewable Energy (%)  Forest Area (%)
# 0                       8                  61.2             13.5
# 1                       9                  32.3             62.1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Year         3 non-null      int64
#  1   CO2          3 non-null      float64
#  2   Temperature  3 non-null      float64
# dtypes: float64(2), int64(1)
# memory usage: 204.0 bytes

# %%
import pandas as pd
df = pd.read_excel("data/climatechangeds.xlsx")



df.to_csv("data/climatechangeds.csv", index = False)
